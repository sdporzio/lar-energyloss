# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from importlib import reload
import betheBloch_library as bbl

# %%
reload(bbl)

en = np.logspace(2,5,10000)
pi = 139.5
bb_pi = [bbl.BetheBloch(pi,e)[1] for e in en]
mpv_pi = [bbl.MPV(pi,e)[1] for e in en]
en_pi = [bbl.BetheBloch(pi,e)[0] for e in en]

mu = 105.65
bb_mu = [bbl.BetheBloch(mu,e)[1] for e in en]
mpv_mu = [bbl.MPV(mu,e)[1] for e in en]
en_mu = [bbl.BetheBloch(mu,e)[0] for e in en]

p = 938.27
bb_p = [bbl.BetheBloch(p,e)[1] for e in en]
mpv_p = [bbl.MPV(p,e)[1] for e in en]
en_p = [bbl.BetheBloch(p,e)[0] for e in en]

plt.figure(figsize=(6,4),facecolor='white',dpi=100)
plt.plot(en_pi,bb_pi,color='C2',lw=3,label='$\pi$ Mean')
plt.plot(en_mu,bb_mu,color='C0',lw=3,label='$\mu$ Mean')
plt.plot(en_p,bb_p,color='C3',lw=3,label='$p$ Mean')
plt.plot(en_pi,mpv_pi,color='C2',ls='--',lw=3,label='$\pi$ MPV')
plt.plot(en_mu,mpv_mu,color='C0',ls='--',lw=3,label='$\mu$ MPV')
plt.plot(en_p,mpv_p,color='C3',ls='--',lw=3,label='$p$ MPV')
plt.grid(ls='--',color='gray',alpha=0.2)
plt.xscale('log')
plt.xlim(10,1e5)
plt.ylim(1.5,4.5)
plt.xlabel('Kinetic Energy [MeV]')
plt.ylabel('dE/dx [MeV/cm]')
plt.legend(bbox_to_anchor=(0, -0.15, 1, 0), loc=2, ncol=2, mode="expand", borderaxespad=0, frameon=False)
plt.show()

# %%
reload(bbl)
mean_dist, mean_dedx, mpv_dist, mpv_dedx = bbl.ResRange(105.65)

plt.figure(figsize=(6,4),facecolor='white',dpi=100)
plt.plot(mean_dist,mean_dedx,color='C0',lw=3,label='$\pi$ Mean')
plt.plot(mpv_dist,mpv_dedx,color='C0',ls='--',lw=3,label='$\pi$ MPV')
plt.grid(ls='--',color='gray',alpha=0.2)
plt.xlim(0,400)
plt.ylim(1,4.)
plt.xlabel('Kinetic Energy [MeV]')
plt.ylabel('dE/dx [MeV/cm]')
plt.legend(bbox_to_anchor=(0, -0.15, 1, 0), loc=2, ncol=2, mode="expand", borderaxespad=0, frameon=False)
plt.show()
